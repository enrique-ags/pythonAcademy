# %%
#Homework:
#Create a python script:
#create list of 100 random numbers from 0 to 1000
import random
random_numbers = []

for x in range(0,100):
    random_numbers.append(random.randint(1,1000))

# %%
#sort list from min to max (without using sort())
a=0
b=0

for x in range(0,len(random_numbers)):
    for y in range(0,len(random_numbers)):
        a = random_numbers[x]
        b = random_numbers[y]
        if b > a:
            random_numbers[x]=b
            random_numbers[y]=a
        

        
    
random_numbers
# Out:
# [19,
#  26,
#  33,
#  43,
#  56,
#  56,
#  57,
#  63,
#  69,
#  83,
#  109,
#  134,
#  140,
#  140,
#  171,
#  173,
#  177,
#  177,
#  177,
#  185,
#  187,
#  189,
#  210,
#  223,
#  229,
#  229,
#  229,
#  230,
#  249,
#  253,
#  271,
#  271,
#  282,
#  285,
#  287,
#  341,
#  362,
#  381,
#  385,
#  396,
#  409,
#  430,
#  449,
#  458,
#  472,
#  473,
#  488,
#  503,
#  503,
#  530,
#  535,
#  538,
#  563,
#  567,
#  594,
#  601,
#  602,
#  602,
#  602,
#  615,
#  625,
#  633,
#  636,
#  638,
#  670,
#  673,
#  679,
#  727,
#  736,
#  741,
#  765,
#  765,
#  767,
#  768,
#  772,
#  777,
#  779,
#  783,
#  790,
#  796,
#  803,
#  812,
#  828,
#  832,
#  839,
#  845,
#  852,
#  860,
#  900,
#  914,
#  916,
#  922,
#  934,
#  949,
#  963,
#  970,
#  982,
#  989,
#  995,
#  996]

# %%
even=0
count_even=0
count_od=0
od=0
for x in random_numbers:
    if x%2==0:
        even+=x
        count_even+=1
    else:
        od+=x
        count_od+=1

print('Sum evens: ',even)
print('Count evens: ',count_even)
print('Avg evens: ',even/count_even)
print('''''''''''''''''''''''''''''')
print('Sum ods: ',od)
print('Count ods: ',count_od)
print('Avg ods: ',od/count_od)
# Out:
# Sum evens:  24872
# Count evens:  42
# Avg evens:  592.1904761904761
#
# Sum ods:  25860
# Count ods:  58
# Avg ods:  445.86206896551727
